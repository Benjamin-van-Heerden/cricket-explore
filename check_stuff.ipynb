# %%
import pandas as pd

# %%
df = pd.read_csv("./IPL_Matches_2008_2022.csv")
df = df.drop(columns=["City", "Venue", "method", "Player_of_Match", "Umpire1", "Umpire2", "Team1Players", "Team2Players"])
# TODO:  What are these No result matches and why are they there?
# df.dropna(inplace=True)

df.head()
# Out:
#         ID        Date Season  MatchNumber                        Team1  \
# 0  1312200  2022-05-29   2022        Final             Rajasthan Royals
# 1  1312199  2022-05-27   2022  Qualifier 2  Royal Challengers Bangalore
# 2  1312198  2022-05-25   2022   Eliminator  Royal Challengers Bangalore
# 3  1312197  2022-05-24   2022  Qualifier 1             Rajasthan Royals
# 4  1304116  2022-05-22   2022           70          Sunrisers Hyderabad
#
#                   Team2            TossWinner TossDecision SuperOver  \
# 0        Gujarat Titans      Rajasthan Royals          bat         N
# 1      Rajasthan Royals      Rajasthan Royals        field         N
# 2  Lucknow Super Giants  Lucknow Super Giants        field         N
# 3        Gujarat Titans        Gujarat Titans        field         N
# 4          Punjab Kings   Sunrisers Hyderabad          bat         N
#
#                    WinningTeam    WonBy  Margin
# 0               Gujarat Titans  Wickets     7.0
# ...

# %%
df[df["SuperOver"] != "N"]
# Out:
#           ID        Date   Season MatchNumber                        Team1  \
# 114  1254077  2021-04-25     2021          20               Delhi Capitals
# 158  1216512  2020-10-18  2020/21          35        Kolkata Knight Riders
# 159  1216517  2020-10-18  2020/21          36               Mumbai Indians
# 184  1216547  2020-09-28  2020/21          10  Royal Challengers Bangalore
# 192  1216493  2020-09-20  2020/21           2               Delhi Capitals
# 203  1178426  2019-05-02     2019          51               Mumbai Indians
# 205  1178424  2019-04-30     2019          49  Royal Challengers Bangalore
# 244  1175365  2019-03-30     2019          10        Kolkata Knight Riders
# 339  1082625  2017-04-29     2017          35                Gujarat Lions
# 437   829813  2015-05-17     2015          55  Royal Challengers Bangalore
# 464   829763  2015-04-29     2015          29  Royal Challengers Bangalore
# ...
